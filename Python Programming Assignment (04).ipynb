# %%
# Python Programming Assignment (04) By Certified Python Programming By Jawan Pakistan
# Note: Sir Kindly Check All Tasks & All Options Inside Tasks

# %%
# Task (01):

# %%
# Option (01 Using Power Function):

num1 = int(input("Enter Your Num1: " + "\n"))
operator = input("Enter Your Operator: " + "\n")
num2 = int(input("Enter Your Num2: " + "\n"))
 
if operator == "+" : 
    print("Answer Is: ", num1 + num2, "\n")
elif operator == "-" : 
    print("Answer Is: ", num1 - num2, "\n")
elif operator == "*" : 
    print("Answer Is: ", num1 * num2, "\n")
elif operator == "/" : 
    print("Answer Is: ", num1 / num2, "\n")
elif operator == "%" : 
    print("Answer Is: ", num1 % num2, "\n")
elif operator == "^" : 
    print("Answer Is: ", pow(num1, num2), "\n")
else :
      print("Make a Mistake!")



# Option (02 Using Python Condition):

# num1 = int(input("Enter Your Num1: "))
# operator = input("Enter Your Operator: ")
# num2 = int(input("Enter Your Num2: "))
 
# Output = ""
    
# if operator == "+" :
#     Output = num1 + num2
#     print("Answer Is: ", Output)
# elif operator == "-" :
#     Output = num1 - num2
#     print("Answer Is: ", Output)
# elif operator == "*" :
#     Output = num1 * num2
#     print("Answer Is: ", Output)
# elif operator == "/" :
#     Output = num1 / num2
#     print("Answer Is: ", Output)
# elif operator == "%" :
#     Output = num1 % num2
#     print("Answer Is: ", Output)
# else :
#     Output = "Make a Mistake!"
#     print("Answer Is: ", Output)

# if(Output == "Make a Mistake!"):
#     print("☹️")

# else:
#     val = input("You know the power of your output. If you want to know so type yes/no. " );
#     if(val == "yes"):
#         power = int(input("Enter Your Power Number: "))
#         base = int(Output)
#         exponent = int(power)

#         result = 1

#         for exponent in range(exponent, 0, -1):
#             result *= int(base)
#             print("Answer Is: " + str(result))
    
#     else:
#         print("Thanks For Your Answer...")
# Out:
# Enter Your Num1:
# 5
# Enter Your Operator:
# ^
# Enter Your Num2:
# 5
# Answer Is:  3125

# %%
# Task (02):

# %%
# Option (01 Using Python For Loop):

lst = ["Mark", 34, "Ace", 45, 8, "Myers", 87]

for list1 in lst:
    if(type(list1) == int):
        print("Integer: ", list1 , " True", "\n")
    elif(type(list1) == str):
        print("String: ", list1 , " False", "\n")
        
    
    
# Option (02 Only integer Numbers Printed):

# lst = ["Mark", 34, "Ace", 45, 8, "Myers", 87]

# for list1 in lst:
#     if(type(list1) == int):
#         print(list1 , "\n")
# Out:
# String:  Mark  False
#
# Integer:  34  True
#
# String:  Ace  False
#
# Integer:  45  True
#
# Integer:  8  True
#
# String:  Myers  False
#
# Integer:  87  True

# %%
# Task (03):

# %%
# Option (01 Using Update Function):

obj = {
    0: "Mark",
    1: "Ace"
}

print(obj)
obj.update({2: "Myers"})
print(obj)



# Option (02 Using Python Condition):

# obj = {
#     0: "Mark",
#     1: "Ace"
# }

# print(obj)
# obj[2] = "Myers"
# print(obj)



# Option (03 Using SetDefault Function):

# obj = {
#     0: "Mark",
#     1: "Ace"
# }

# print(obj)
# obj.setdefault(2, "Myers")
# print(obj)



# Option (04 Using Python Condition With User Input):

# key = input("Enter Key: ")
# val = input("Enter Value: ")

# obj = {
#     0: "Mark",
#     1: "Ace"
# }

# print(obj)
# obj[key] = val
# print(obj)
# Out:
# {0: 'Mark', 1: 'Ace'}
# {0: 'Mark', 1: 'Ace', 2: 'Myers'}

# %%
# Task (04):

# %%
# Option (01 Using Set Function):

obj = {
    "1": 5,
    "2": 6,
    "3": 8,
}

comp_val = sum(obj.values())
print(comp_val)



# Option (02 Using Set Function With Key & Values):

# obj = {
#     1: 5,
#     2: 6,
#     3: 8,
# }

# comp_key = sum(obj.keys())
# comp_val = sum(obj.values())

# print("Addition Key", comp_key)
# print("Addition Value", comp_val)



# Option (03 Using Set Function With Use a new Key & Values in OBJ After Addition):

# obj = {
#     1: 5,
#     2: 6,
#     3: 8,
# }

# comp_key = sum(obj.keys()) # Addtion Key
# comp_val = sum(obj.values()) # Addtion Value

# print(obj)

# obj[comp_key] = comp_val # Add Addition Key & Value In Old OBJ

# print(obj)

# obj1 = {
#     comp_key: comp_val # Create a new OBJ Then Add Addition Key & Value
# }

# print(obj1)



# Option (04 Using For Loop With Set Function):

# obj = {
#     "1": 5,
#     "2": 6,
#     "3": 8,
# }

# new = {i for i in obj.values()}
# print(sum(new))
# Out:
# 19

# %%
# Task (05):

# %%
# Option (01 Using For Loop || List || Condition & Append Function):

list1=["Mark", "Ace", "Mark", "Myers", "Hong", "Ace"]

list2=[]

for i in list1:
    if i not in list2:
        list2.append(i)
    else:
        print("Duplicate Value: ", i, " True", end='\n')



# Option (02 Using For Loop || Def Function || Condition & Range Function):

# def duplicate(li):
#     n=len(li)
#     dup=[]
#     for i in range(n):
#         k = i + 1
#         for j in range(k,n):
#             if li[i] == li[j] and li[i] not in dup:
#                 dup.append(li[i])
#     return dup

# list1=[0,1,2,0,3,1,4,5,6,2,5]

# print("Duplicate Value: ",duplicate(list1))



# Option (03 Using Python Condition & Print Answer True || False):

# def checkIfDuplicates_1(listOfElems):
#     ''' Check if given list contains any duplicates '''
#     if len(listOfElems) == len(set(listOfElems)):
#         return False
#     else:
#         return True

# listOfElems = ['Hello', 'Ok', 'is', 'Ok', 'test', 'this', 'is', 'a', 'test']
# result = checkIfDuplicates_1(listOfElems)
# if result:
#     print('Yes, list contains duplicates')
# else:
#     print('No duplicates found in list')
# Out:
# Duplicate Value:  Mark  True
# Duplicate Value:  Ace  True

# %%
# Task (06):

# %%
# Option (01 Using Python Condition & Def Function & Print Answer True || False):

d = {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

def is_key_present(x):
    
  if x in d:
      print('Key is present in the dictionary')
  else:
      print('Key is not present in the dictionary')
        
is_key_present(5)
is_key_present(9)



# Option (02 Using Python Condition With User Input):

# dict = {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# def check_existence(dict):
#     check = int(input("What you want to check for: "))
#     if check in dict:
#         print("Your shit is in the dictionary with the value of " + str(dict[check]))

# check_existence(dict)



# Option (03 Using if and in):

# def checkKey(dict, key):
      
#     if key in dict:
#         print("Present, ", end =" ")
#         print("value =", dict[key])
#     else:
#         print("Not present")
  
# dict = {'a': 100, 'b':200, 'c':300}
  
# key = 'b'
# checkKey(dict, key)
  
# key = 'w'
# checkKey(dict, key)
# Out:
# Key is present in the dictionary
# Key is not present in the dictionary
